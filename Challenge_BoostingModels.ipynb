# %% [markdown]
# # Boosting Models
#
# ## Challenge: what model can answer this question?
#
#
# by: Melissa N

# %% [markdown]
# You now have a fairly substantial starting toolbox of supervised learning methods that you can use to tackle a host of exciting problems. To make sure all of these ideas are organized in your mind, please go through the list of problems below. For each, identify which supervised learning method(s) would be best for addressing that particular problem. Explain your reasoning and discuss your answers with your mentor.

# %% [markdown]
# 1.Predict the running times of prospective Olympic sprinters using data from the last 20 Olympics.
#
# __Linear Regression__
# This allows us to predict continuous variables.
# This model learns through errors, OLS uses the estimatoors to minimixe the error.
#
#
# 2.You have more features (columns) than rows in your dataset.
#
# __SVM__
# This is because using hyperpplanes, SVM can transform the data and divide it in  different classes depending on the output we need
#
# __Ridge/Lasso Regression__
# For Ridge, if the model becomes increasingly complex and features correlate with one another more and more, coefficients arrived at by OLS becomes large.
#
#
#
# 3.Identify the most important characteristic predicting likelihood of being jailed before age 20.
#
# __KNN Classifier__
# We can look at several of the nearest K neighbors for each outcome to identify the characteristics we need.
# this is a similarity model
#
#
# __Decision Tree__
# Using the decision tree, we can ask at each step particular questions to be able to get the result we need.
# This can handle varied types of data.
#
#
# 4.Implement a filter to “highlight” emails that might be important to the recipient.
#
# __Naive Bayes__
# This is used for Spam Filter and thus can be useful here.
# It will give low false positive error (Type I errors) wich is good for  spam detection
#
#
#
# 5.You have 1000+ features.
#
# __LASSO Regression__
# Non important features or small parameters estimates will be reduced to zero for Lasso in Particular.
# Lasso is extremel handy when you are dealing with thousands or hundred of thousands of predictors.
#
#
# __Random Forest__
# Random Forest algorithm randomly selects observations and features to build several decision trees and then averages the results
# Can be used to train the data
# Random Forest is a predictive modeling tool and not a descriptive tool.
#
#
#
# 6.Predict whether someone who adds items to their cart on a website will purchase the items.
#
# __Logistic Regression__
# The outcome can be separated in Buyer and Non-Buyer and thus give us a binary outcome which is good for Logistic Regression
#
# __Naive Bayes__
# Variables are independe of each other.
# Takes 2 possible outcome with the outcome variable being binary (Buyer and Non_Buyer)
#
#
#
#
# 7.Your dataset dimensions are 982400 x 500
#
# __Random Forest__
# We can set the parameters for both the trees and the forest
# Can be used to train the data
# Random Forest is a predictive modeling tool and not a descriptive tool.
#
#
# __LASSO Regression__
# Non important features or small parameters estimates will be reduced to zero for Lasso in Particular.
# Lasso is extremel handy when you are dealing with thousands or hundred of thousands of predictors.
#
#
# 8.Identify faces in an image.
#
# __KNN Classifier__
# We can look at several of the nearest K neighbors for each outcome to identify the characteristics we need.
# This is a similarity model.
#
# __SVM__
# This is because using hyperpplanes, SVM can transform the data and divide it in  different classes depending on the output we need
#
#
# 9.Predict which of three flavors of ice cream will be most popular with boys vs girls.
#
# __Logistic Regression__
# This is used when the dependent variable is categorical/binary (Boys and Girls)
# We are interested i predicing the proobability of an outcome for situation where the outcome is categorical and not continuous.
#
# __SVM__
# We can separate the data into the boys and Girls and see which of the three flavor is popular in each separate group.
